# %%
import trimesh
import os

# %%
def rescale_mesh(name):
    
    src_dir = os.path.join('./car_60_rescale/' + name)
    
    mesh = trimesh.load(src_dir)
#     #rescale the mesh to real scale in meters
#     mesh.vertices = mesh.vertices*5
#     mesh.vertices -= mesh.center_mass
    
#     tar_dir = os.path.join('./car_60_rescale/' + name)
    
#     mesh.export(tar_dir)
    
    bbx_ex = mesh.bounding_box.primitive.extents
    print(bbx_ex)
    
    return 

# name = "big3.obj"
# rescale_mesh(name)

# %%
#rescale all models
names = [f for f in os.listdir('./car_60_rescale/')]
# print(names)
for name in names:
    rescale_mesh(name)
# Out:
# [4.31629  1.518525 1.76892 ]
# [4.450855 1.52779  1.687985]
# [4.31318  1.441975 1.956815]
# [4.26939 1.61307 1.69462]
# [4.30527  1.55678  1.973165]
# [4.30079  1.395875 1.82041 ]
# [4.301435 1.48876  1.942705]
# [4.309825 1.437975 1.8349  ]
# [4.134235 1.641935 1.98257 ]
# [4.181405 1.665035 1.862875]
# [4.276135 1.65029  1.749255]
# [4.29977  1.388045 2.075675]
# [4.27864  1.655475 1.83327 ]
# [4.399285 1.40225  1.601275]
# [4.272665 1.509955 1.782005]
# [4.352255 1.45958  1.74009 ]
# [4.314935 1.605735 1.788895]
# [4.34106  1.44569  1.682405]
# [4.25821  1.493625 2.10489 ]
# [4.469165 1.21137  1.74954 ]
# [4.491535 1.189095 1.763935]
# [4.1282   1.891845 1.95385 ]
# [4.426975 1.373025 1.725905]
# [4.49001  1.24467  1.654395]
# [4.43836  1.21706  1.830345]
# [4.41271  1.22297  1.825995]
# [4.491075 1.21762  1.767815]
# [4.42294  1.23968  1.747085]
# [4.38543  1.450335 1.87971 ]
# [4.394495 1.2723   1.692425]
# [4.42074 1.35465 1.68235]
# [4.371515 1.357215 1.74407 ]
# ...
